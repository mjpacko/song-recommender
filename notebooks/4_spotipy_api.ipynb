# %% [markdown]
# Imports

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import time
import os
from dotenv import load_dotenv
import pandas as pd

# Load environment variables
load_dotenv()
# Out:
# True

# %%
# Set up authentication
client_credentials_manager = SpotifyClientCredentials(
    client_id=os.getenv('SPOTIPY_CLIENT_ID'),
    client_secret=os.getenv('SPOTIPY_CLIENT_SECRET')
)

# Create Spotify client
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Read the CSV file
df_input = pd.read_csv('../data/3_combined_cleaned_df.csv')

# %%
# Initialize list to store track data
all_track_data = []

# Process each track
for index, row in df_input.iterrows():
    try:
        # Clean artist name by removing "Featuring" and anything after it
        artist_name = row['artist'].split('Featuring')[0].strip()
        
        # Clean track name by removing content in parentheses and square brackets
        track_name = row['title']
        # Remove content in parentheses
        if '(' in track_name:
            track_name = track_name.split('(')[0]
        # Remove content in square brackets
        if '[' in track_name:
            track_name = track_name.split('[')[0]
        track_name = track_name.strip()
        
        # Add 30-second pause every 50 tracks
        if index > 0 and index % 50 == 0:
            print(f"\nPausing for 30 seconds after processing {index} tracks...")
            time.sleep(30)
            print("Resuming processing...")
        
        # Create search query from cleaned title and artist
        search_query = f"track:{track_name} artist:{artist_name}"
        
        # Search for the track
        results = sp.search(q=search_query, type='track', limit=1)
        
        if results['tracks']['items']:
            track = results['tracks']['items'][0]
            
            # Get artist's genres
            artist_id = track['artists'][0]['id']
            artist_info = sp.artist(artist_id)
            genres = artist_info['genres']
            
            # Create track data dictionary
            track_data = {
                'name': track['name'],
                'artist': track['artists'][0]['name'],
                'uri': track['uri'],
                'popularity': track['popularity'],
                'album_name': track['album']['name'],
                'release_date': track['album']['release_date'],
                'album_art_url': track['album']['images'][0]['url'] if track['album']['images'] else None,
                'genres': ', '.join(genres) if genres else 'No genres available'
            }
            
            all_track_data.append(track_data)
            
            # Print progress
            if index % 10 == 0:
                print(f"Processed {index} tracks...")
            
            # Save intermediate results every 200 tracks
            if (index + 1) % 200 == 0:
                print(f"\nSaving intermediate results at {index + 1} tracks...")
                temp_df = pd.DataFrame(all_track_data)
                temp_df.to_csv('../data/spotify_track_data.csv', index=False)
                print("Intermediate results saved!")
            
            # Add a small delay between each track
            time.sleep(0.5)
            
        else:
            print(f"Track not found: {track_name} by {artist_name}")
            
    except Exception as e:
        print(f"Error processing track {track_name} by {artist_name}: {str(e)}")
        continue

# Create final DataFrame
df_spotify = pd.DataFrame(all_track_data)

# Display info about the results
print("\nProcessing complete!")
print(f"Successfully retrieved data for {len(df_spotify)} tracks")

# Save final results
df_spotify.to_csv('../data/spotify_track_data.csv', index=False)
print("\nFinal results saved to '../data/spotify_track_data.csv'")
# Out:
# Error processing track Die With A Smile by Lady Gaga & Bruno Mars: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=5)
# Error processing track Bad Dreams by Teddy Swims: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Processed 10 tracks...
# Processed 20 tracks...
# Processed 30 tracks...
# Processed 40 tracks...
#
# Pausing for 30 seconds after processing 50 tracks...
# Resuming processing...
# Processed 50 tracks...
# Processed 60 tracks...
# Processed 70 tracks...
# Processed 80 tracks...
# Track not found: 4x4xU by Lainey Wilson
# Processed 90 tracks...
#
# Pausing for 30 seconds after processing 100 tracks...
# Resuming processing...
# Processed 100 tracks...
# Processed 110 tracks...
# Processed 120 tracks...
# Track not found: Get Together - Album Version by Randy Stonehill
# Processed 130 tracks...
# Processed 140 tracks...
#
# Pausing for 30 seconds after processing 150 tracks...
# Resuming processing...
# Processed 150 tracks...
# Processed 160 tracks...
# Track not found: Death Adventure by Pumpkin Buzzard
# Processed 170 tracks...
# Track not found: Peyte Pivo Pennoe by Kruger
# Processed 180 tracks...
# Processed 190 tracks...
#
# Saving intermediate results at 200 tracks...
# Intermediate results saved!
#
# Pausing for 30 seconds after processing 200 tracks...
# Resuming processing...
# Processed 200 tracks...
# Track not found: By My Spirit by Eden's Bridge
# Processed 210 tracks...
# Track not found: Supertouch/shitfit by Hatebreed
# Processed 220 tracks...
# Processed 230 tracks...
# Processed 240 tracks...
# Track not found: Rock Me Baby - Live by Hound Dog Taylor and The Houserockers
# Track not found:  by Tony Mathews
# Track not found:  by La Bergère
#
# Pausing for 30 seconds after processing 250 tracks...
# Resuming processing...
# Processed 250 tracks...
# Track not found: Alexander's Ragtime Band by Ray Conniff;Billy Butterfield
# Processed 260 tracks...
# Track not found: Freak Break by Lady Saw
# Track not found: Night Shift by Ashbrg
# Processed 270 tracks...
# Processed 280 tracks...
# Track not found: I'll Be There For You by The Chinese
# Track not found: The Three X's by Electric O & Ishkan
# Track not found: Declaration by Kirk Franklin
# Track not found: Jesus by Gran Coquivacoa
#
# Pausing for 30 seconds after processing 300 tracks...
# Resuming processing...
# Processed 300 tracks...
# Track not found: Blackfoot Allstars by Blackfoot
# Processed 310 tracks...
# Track not found: When I Fall In Love by T.G.Sheppard
# Processed 320 tracks...
# Track not found: What You Made Me by Ghost Machine
# Processed 330 tracks...
# Track not found: Sample Track 18 by Simon Harris
# Track not found: Burbullas A Grella by Xose Manuel Budiño
# Processed 340 tracks...
# Track not found: Percutindo by Djalma Correa
#
# Pausing for 30 seconds after processing 350 tracks...
# Resuming processing...
# Processed 350 tracks...
# Processed 360 tracks...
# Track not found: I Luv Dat Too by D.O.W.N.
# Processed 370 tracks...
# Processed 380 tracks...
# Track not found: Smpty spaces missing units by Pitch Black
# Processed 390 tracks...
#
# Saving intermediate results at 400 tracks...
# Intermediate results saved!
#
# Pausing for 30 seconds after processing 400 tracks...
# Resuming processing...
# Processed 400 tracks...
# Processed 410 tracks...
# Track not found: Sparnuotoji Doze. Laukimas by Svartthron
# Processed 420 tracks...
# Processed 430 tracks...
# Track not found: Ver de Feliz by BT
# Track not found: Back From The Garden by S.U.P
# Track not found: Jump N Shout Featuring Slarta John by Basement Jaxx
# Processed 440 tracks...
# Track not found: Suk The Blood by Lil Mz. 313 featuring DJ Rashad
#
# Pausing for 30 seconds after processing 450 tracks...
# Resuming processing...
# Processed 450 tracks...
# Track not found: The Best Of Radio Roy 1 by Mario Rosenstock
# Track not found: Tian Cai Yu Bai Chi Zhi Tian Cai Bai Chi Meng by Leo Ku
# Track not found: Lullaby For The Dead In Our Life by Lexie Mountain Boys
# Processed 790 tracks...
#
# Saving intermediate results at 800 tracks...
# Intermediate results saved!
#
# Pausing for 30 seconds after processing 800 tracks...
# Resuming processing...
# Processed 800 tracks...
# Processed 810 tracks...
# Processed 820 tracks...
# Track not found: Fruits & Nuts by Marc Shaiman
# Processed 830 tracks...
# Processed 840 tracks...
# Track not found: White Winter Hymnal by Catherine Howe & Vo Fletcher
#
# Pausing for 30 seconds after processing 850 tracks...
# Resuming processing...
# Processed 850 tracks...
# Processed 860 tracks...
# Track not found: Swing by Jean-michel Rotin
# Processed 870 tracks...
# Processed 880 tracks...
# Track not found: Voodoo Punnany by Joe Rogan
# Track not found: 18 Carat Garbage by Billie Ray Martin Feat. Ann Peebles
# Track not found: Jingle Bells by Maddox Brothers and Rose
#
# Pausing for 30 seconds after processing 900 tracks...
# Resuming processing...
# Processed 900 tracks...
# Track not found: Watcha Gon Do? by Terror Squad featuring Big Pun
# Processed 910 tracks...
# Processed 920 tracks...
# Track not found: People with honour by Wilks
# Track not found: Love Theme From Night Of Dark Shadows by Dark Shadows
# Processed 930 tracks...
# Track not found: The First Cut Is The Deepest by Little Angels
# Processed 940 tracks...
#
# Pausing for 30 seconds after processing 950 tracks...
# Resuming processing...
# Processed 950 tracks...
# Track not found: Pic & Run by Adam Richmond
# Processed 970 tracks...
# Track not found: mixture of noize by Aphasia
# Processed 980 tracks...
# Processed 990 tracks...
# Track not found: Woo Hoo by Kings Of Leon
# HTTP Error for GET to https://api.spotify.com/v1/search with Params: {'q': "track:Sleepy F%#&in' D artist:Sleepy D", 'limit': 1, 'offset': 0, 'type': 'track', 'market': None} returned 400 due to Invalid string
# Error processing track Sleepy F%#&in' D by Sleepy D: http status: 400, code:-1 - https://api.spotify.com/v1/search?q=track%3ASleepy+F%25%23%26in%27+D+artist%3ASleepy+D&limit=1&offset=0&type=track:
#  Invalid string, reason: None
#
# Saving intermediate results at 1000 tracks...
# Intermediate results saved!
#
# Pausing for 30 seconds after processing 1000 tracks...
# Resuming processing...
# Processed 1000 tracks...
# Processed 1010 tracks...
# Processed 1020 tracks...
# Track not found: Mothers Rastas by Taya wooden
# Processed 1030 tracks...
# Track not found: Ven a Mi by David Saylor
# Processed 1040 tracks...
# Track not found: Los! by Vorstadtkinder
#
# Pausing for 30 seconds after processing 1050 tracks...
# Resuming processing...
# Processed 1050 tracks...
# Track not found: The west's awake by Tony Malone And The Rapparees
# Processed 1060 tracks...
# Track not found: Could You Be Love by Mariano Yanani
# Processed 1070 tracks...
# Track not found: Frigide by Caniche Hara-Kiri
# Processed 1080 tracks...
# Track not found: Two Sweety People by Line Renaud - Dean Martin
# Processed 1090 tracks...
# Track not found: Hound Dog by Big Mama Thornton with Kansas Bill and his Orchestra
#
# Pausing for 30 seconds after processing 1100 tracks...
# Track not found: Hear Me Talkin' To You by Ma Rainey & Her Tub Jug Washboard Band
#
# Pausing for 30 seconds after processing 1400 tracks...
# Resuming processing...
# Processed 1400 tracks...
# Processed 1410 tracks...
# Processed 1420 tracks...
# Track not found: Guillaume Tell_ Acte II by Montserrat Caballé/Royal Philharmonic Orchestra/Lamberto Gardelli
# Processed 1430 tracks...
# Track not found: Zhan Zai Di Yi Pai by Sandy Lam
# Processed 1440 tracks...
#
# Pausing for 30 seconds after processing 1450 tracks...
# Resuming processing...
# Processed 1450 tracks...
# Track not found: Bonus Track by Tigerstyle
# Processed 1460 tracks...
# Track not found: The Muddy Morning Hymn by Shaman
# Processed 1470 tracks...
# Processed 1480 tracks...
# Processed 1490 tracks...
#
# Pausing for 30 seconds after processing 1500 tracks...
# Resuming processing...
# Processed 1500 tracks...
# Track not found: The Hunter by Paul Rogers
# Processed 1510 tracks...
# Processed 1520 tracks...
# Processed 1530 tracks...
# Track not found: Truth And Lies by The Presets
# Processed 1540 tracks...
# Track not found: Can You Feel It? by Lee Ritenour
#
# Pausing for 30 seconds after processing 1550 tracks...
# Resuming processing...
# Track not found: I'm In Love by Dub Pistols feat. Lindy Layton & Rodney P
# Track not found: Wahrheit by Hassan Annouri feat. Cassandra Steen
# Processed 1560 tracks...
# Processed 1570 tracks...
# Track not found: Old Friends by Stanley Clarke;Herbie Hancock
# Processed 1580 tracks...
# Processed 1590 tracks...
# Track not found: B Somebody by Nacho Chapado feat. Stephen Massa
#
# Saving intermediate results at 1600 tracks...
# Intermediate results saved!
#
# Pausing for 30 seconds after processing 1600 tracks...
# Resuming processing...
# Track not found: Tulsa Girl by Dwight Twilley
# Track not found: All Because Of You - Original by Leroy Hutson
# Processed 1610 tracks...
# Processed 1620 tracks...
# Track not found: Teasin' Brown by North Mississippi Allstars
# Processed 1630 tracks...
# Error processing track nan by Sébastien Roch: argument of type 'float' is not iterable
# Processed 1640 tracks...
#
# Pausing for 30 seconds after processing 1650 tracks...
# Resuming processing...
# Track not found: Still Ballin by Messy Marv featuring Clover Geez
# Track not found: A Galicia Vente Xa by Xose Manuel Budiño
# Track not found: Like A Freza by Little Capes
# Track not found: Stereo + Video by D:Fuse vs The Scumfrog
# Processed 1670 tracks...
# Track not found: Life Upon The Wicked Stage by Sophie Tucker
# Track not found: I've Been Cryin' Since You've Been Gone by New Roanoke Jug Band
# Processed 1680 tracks...
# Track not found: Saturday Night's Alright by Nickelback featuring Kid Rock
# Processed 1690 tracks...
# Track not found: The Ghost At #1 by Jellyfish
# Track not found: Dumy Moi-Zamicy Dal Nie... by Alkonost
#
# Pausing for 30 seconds after processing 1700 tracks...
# Resuming processing...
# Processed 1700 tracks...
# HTTP Error for GET to https://api.spotify.com/v1/search with Params: {'q': 'track:100% Dundee artist:The Roots', 'limit': 1, 'offset': 0, 'type': 'track', 'market': None} returned 400 due to Invalid string
# Error processing track 100% Dundee by The Roots: http status: 400, code:-1 - https://api.spotify.com/v1/search?q=track%3A100%25+Dundee+artist%3AThe+Roots&limit=1&offset=0&type=track:
#  Invalid string, reason: None
# Processed 1710 tracks...
# Track not found: Need Not by A Ghost Devotion
# Track not found: Happy Beat by Edmundo Ros
# Processed 1720 tracks...
# HTTP Error for GET to https://api.spotify.com/v1/search with Params: {'q': 'track:100% artist:Cocoa Tea', 'limit': 1, 'offset': 0, 'type': 'track', 'market': None} returned 400 due to Invalid string
# Error processing track 100% by Cocoa Tea: http status: 400, code:-1 - https://api.spotify.com/v1/search?q=track%3A100%25+artist%3ACocoa+Tea&limit=1&offset=0&type=track:
#  Invalid string, reason: None
# Processed 1730 tracks...
# Track not found: Cuore Appassionato by Sergio Franchi
# Processed 1740 tracks...
# Track not found: Soul Etouffe by Jazz Crusaders
#
# Pausing for 30 seconds after processing 1750 tracks...
# Resuming processing...
# Processed 1750 tracks...
# Track not found: Don't Go by Wordsworth feat. Adanita Ross
# Track not found: Myasorubka by Kruger
# Processed 1760 tracks...
# Track not found: Diamond In The Bluff by Memphis Sheiks
# Processed 1770 tracks...
# Track not found: No Mercy Remix by The Last Eighth feat. Dumi Right(Zimbabwe Legit) and Skillz
# Processed 1780 tracks...
# Track not found: Party Favours by Bionikworld
# Processed 1790 tracks...
#
# Saving intermediate results at 1800 tracks...
# Intermediate results saved!
#
# Pausing for 30 seconds after processing 1800 tracks...
# Resuming processing...
# Processed 1800 tracks...
# Processed 1810 tracks...
# Track not found: Problem Inna the System by Black History
# Processed 1820 tracks...
# Track not found: Pu**y Pop by Xzibit featuring Jayo Felony and Method Man
# Processed 1830 tracks...
# Processed 1840 tracks...
# Track not found: Du Verstehst Mich Nicht by Andreas Dorau
#
# Pausing for 30 seconds after processing 1850 tracks...
# Resuming processing...
# Processed 1850 tracks...
# Processed 1860 tracks...
# Track not found: Twelve Gates To The City by John Cephas & Phil Wiggins
# Processed 1870 tracks...
# Processed 1880 tracks...
# Processed 1890 tracks...
# Track not found: Now I'm All Over The Place_ Scoob by Frank Caliendo
#
# Pausing for 30 seconds after processing 1900 tracks...
# Resuming processing...
# Processed 1900 tracks...
# Track not found: The Tube by Spectra Soul
# Track not found: Get Moose and Squirrel by Virgil Moorefield
# Processed 1910 tracks...
# Track not found: Styles P Speaks by Styles P
# Track not found: Certified Gangstas by The Game feat. Jim Jones Camron & Bezell
# Processed 1920 tracks...
# Processed 1930 tracks...
# Track not found: Everything I Need by All Girl Summer Fun Band
# Track not found: Gedroomd by Hef feat. Big2 & Dio
# Processed 1940 tracks...
# Track not found: Signapur by In Extremo
#
# Pausing for 30 seconds after processing 1950 tracks...
# Resuming processing...
# Processed 1950 tracks...
# Track not found: Everyday by Bebe Winans / Stephanie Mills
# Processed 1960 tracks...
# Track not found: Give It To 'Em by Chops
# Track not found: Truck Driving Man/Down In The Caribbean by Leon Russell & New Grass Revival
# Processed 1970 tracks...
# Track not found: Lil Mama Getdown by DJ Spinn featuring Traxman
# Processed 1980 tracks...
('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Track not found: The Fourth Wish by Bruno Sanfilippo
# Track not found: I've Been Working on the Railroad by Laurie Berkner
# Processed 2910 tracks...
# Processed 2920 tracks...
# Track not found: These Foolish Things by Fixx_ The
# Track not found: Békási táncdallamok by Muzsikas
# Processed 2930 tracks...
# Track not found: A Guy What Takes His Time En Anglais by Marlene Dietrich
# Track not found: Percussio Livre by Grupo Batuque
#
# Pausing for 30 seconds after processing 2950 tracks...
# Resuming processing...
# Processed 2950 tracks...
# Track not found: Elizabeth Story_ et al._ Honeybabe_ Your Papa Cares For You by Elizabeth Cotten
# Track not found: Could This Be Love by Leroy Hutson
# Processed 2960 tracks...
# Processed 2970 tracks...
# Track not found: Marine's hymn by The Sun Harbor's Chorus-Documentary Recordings
# Track not found: All Dressed Up by Aram Shelton
# Processed 2980 tracks...
# Processed 2990 tracks...
# Track not found: Hua Yu Ai Li Si by Miriam Yeung
# Track not found: Got You Moving by DJ DLG feat. MC Flipside
#
# Saving intermediate results at 3000 tracks...
# Intermediate results saved!
#
# Pausing for 30 seconds after processing 3000 tracks...
# Resuming processing...
# Processed 3000 tracks...
# Processed 3010 tracks...
# Track not found: Dieter's Theme by Klaus Badelt
# Track not found: Peaches by Dub Pistols feat. Rodney P & Terry Hall
# Track not found: La Pieuvre by Lara
# Processed 3020 tracks...
# Track not found: Apostasie by Konexion
# Processed 3030 tracks...
# Track not found: At the Club by DJ X-Change featuring DJ Omega
# Processed 3040 tracks...
# Track not found: The Friendly Visit / The Stack of Wheat / The Gypsy Hornpipe by Joe Derrane_ Frankie Gavin_ Brian McGrath
#
# Pausing for 30 seconds after processing 3050 tracks...
# Resuming processing...
# Processed 3050 tracks...
# Processed 3060 tracks...
# Track not found: Rebel Music by Wyclef Jean featuring Prodigy of Mobb Deep
# Track not found: Italian Concerto in F_ BWV 971 - Allegro by Camerata Brasil
# Track not found: You Should Be Free by Bruce Rowland
# Processed 3070 tracks...
# Processed 3080 tracks...
# Track not found:  by Eagles Of Death Metal
# Processed 3090 tracks...

# %%
# Search for the specific track
results = sp.search(q='track:Espresso artist:Sabrina Carpenter', type='track', limit=1)

if results['tracks']['items']:
    track = results['tracks']['items'][0]
    
    # Get artist's genres
    artist_id = track['artists'][0]['id']
    artist_info = sp.artist(artist_id)
    
    # Get audio features
    audio_features = sp.audio_features(track['id'])[0]
    
    print("Track Information:")
    print(f"Name: {track['name']}")
    print(f"Artist: {track['artists'][0]['name']}")
    print(f"Album: {track['album']['name']}")
    print(f"Release Date: {track['album']['release_date']}")
    print(f"Popularity: {track['popularity']}/100")
    print(f"URI: {track['uri']}")
    print(f"\nArtist Genres: {', '.join(artist_info['genres']) if artist_info['genres'] else 'No genres available'}")

else:
    print("Track not found")

# %%
# Test API connection
try:
    test_result = sp.search(q='track:Espresso artist:Sabrina Carpenter', type='track', limit=1)
    print("API Connection Test: Successful")
except Exception as e:
    print(f"API Connection Test Failed: {str(e)}")
    raise  # Stop execution if we can't even make a test request

# %%
# Read the CSV file
df_input = pd.read_csv('../data/3_combined_cleaned_df.csv')

# %%
# Test with just one row
test_row = df_input.iloc[0]
print("Testing with track:", test_row['title'], "by", test_row['artist'])

try:
    # Clean artist name
    artist_name = test_row['artist'].split('Featuring')[0].strip()
    print("Cleaned artist name:", artist_name)
    
    # Clean track name
    track_name = test_row['title']
    if '(' in track_name:
        track_name = track_name.split('(')[0]
    if '[' in track_name:
        track_name = track_name.split('[')[0]
    track_name = track_name.strip()
    print("Cleaned track name:", track_name)
    
    # Create and print search query
    search_query = f"track:{track_name} artist:{artist_name}"
    print("Search query:", search_query)
    
    # Search with timeout
    print("Sending API request...")
    results = sp.search(q=search_query, type='track', limit=1)
    print("Got results:", bool(results['tracks']['items']))
    
    if results['tracks']['items']:
        track = results['tracks']['items'][0]
        print("Found track:", track['name'], "by", track['artists'][0]['name'])
except Exception as e:
    print(f"Error occurred: {str(e)}")

# %%
# Test with first 5 rows
for index, row in df_input.head().iterrows():
    print(f"\nProcessing row {index}")
    try:
        # Clean artist name
        artist_name = row['artist'].split('Featuring')[0].strip()
        
        # Clean track name
        track_name = row['title']
        if '(' in track_name:
            track_name = track_name.split('(')[0]
        if '[' in track_name:
            track_name = track_name.split('[')[0]
        track_name = track_name.strip()
        
        print(f"Searching for: {track_name} by {artist_name}")
        
        # Search for the track
        results = sp.search(q=f"track:{track_name} artist:{artist_name}", type='track', limit=1)
        
        if results['tracks']['items']:
            print("Found match!")
        else:
            print("No match found")
            
    except Exception as e:
        print(f"Error: {str(e)}")
        continue

# %%
# Test with just the first row with detailed debugging
import requests.exceptions
from requests.exceptions import ReadTimeout, ConnectionError

test_row = df_input.iloc[0]
print("Test row data:")
print(f"Title: {test_row['title']}")
print(f"Artist: {test_row['artist']}")

try:
    # Clean artist name
    artist_name = test_row['artist'].split('Featuring')[0].strip()
    print("Cleaned artist name:", artist_name)
    
    # Clean track name
    track_name = test_row['title']
    if '(' in track_name:
        track_name = track_name.split('(')[0]
    if '[' in track_name:
        track_name = track_name.split('[')[0]
    track_name = track_name.strip()
    print("Cleaned track name:", track_name)
    
    # Create and print search query
    search_query = f"track:{track_name} artist:{artist_name}"
    print("Search query:", search_query)
    
    # Search with explicit timeout
    print("Sending API request...")
    results = sp.search(
        q=search_query, 
        type='track', 
        limit=1, 
        requests_timeout=5  # 5 second timeout
    )
    print("Request completed!")
    
    if results['tracks']['items']:
        track = results['tracks']['items'][0]
        print("Found track:", track['name'], "by", track['artists'][0]['name'])
    else:
        print("No matching tracks found")
        
except ReadTimeout:
    print("Request timed out after 5 seconds")
except ConnectionError:
    print("Connection error occurred")
except spotipy.exceptions.SpotifyException as e:
    print(f"Spotify API error: {str(e)}")
    if hasattr(e, 'http_status'):
        print(f"HTTP Status: {e.http_status}")
    if hasattr(e, 'headers'):
        print(f"Response Headers: {e.headers}")
except Exception as e:
    print(f"Unexpected error: {str(e)}")
    print(f"Error type: {type(e)}")

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# Load the scaled dataset
df_scaled = pd.read_csv('../data/6_spotify_scaled_cleaned.csv')
# Store original column order
original_columns = df_scaled.columns.tolist()
print("Dataset shape:", df_scaled.shape)
# Out:
# Dataset shape: (7282, 53)

# %% [markdown]
# KMeans Clustering and Dataset training

# %%
# Initialize and train KMeans model
kmeans = KMeans(n_clusters=53, random_state=42)
cluster_labels = kmeans.fit_predict(df_scaled)

# Add cluster labels to the dataframe and reorder columns
df_scaled['cluster'] = cluster_labels
df_scaled = df_scaled[original_columns + ['cluster']]

# Display cluster distribution
cluster_dist = df_scaled['cluster'].value_counts().sort_index()
print("\nCluster distribution (number of songs in each cluster):")
display(cluster_dist)
# Out:
# Cluster distribution (number of songs in each cluster):
# cluster
# 0     6212
# 1        1
# 2       43
# 3       15
# 4       11
# 5        2
# 6       24
# 7       16
# 8       36
# 9       30
# 10      31
# 11       3
# 12      16
# 13      13
# 14      22
# 15      26
# 16      15
# 17      28
# 18      21
# 19      15
# 20      37
# 21      21
# 22      22
# 23      52
# 24      18
# 25       1
# 26       3
# 27      18
# 28      19
# 29       2
# 30      18
# 31      32
# 32      15
# 33      16
# 34      16
# 35      17
# 36      19
# 37       1
# 38      20
# 39      22
# 40      87
# 41       4
# 42      48
# 43       6
# 44      16
# 45      51
# 46      23
# 47      25
# 48       9
# 49       8
# 50      24
# 51      11
# 52      21
# Name: count, dtype: int64

# %%
# Save the model
import joblib
joblib.dump(kmeans, '../models/kmeans_model.joblib')

# Save the clustered dataset
df_scaled.to_csv('../data/7_spotify_clustered.csv', index=False)
print("Model and clustered dataset saved successfully!")
# Out:
# Model and clustered dataset saved successfully!

# %%
# Analyze cluster characteristics
cluster_centers = pd.DataFrame(
    kmeans.cluster_centers_,
    columns=original_columns  # Use original column order
)

# For each cluster, find the most prominent features
for cluster in range(53):
    print(f"\nCluster {cluster} characteristics:")
    # Get the top 5 most prominent features (highest absolute values)
    cluster_features = cluster_centers.iloc[cluster].abs().sort_values(ascending=False).head(5)
    print(cluster_features)
# Out:
# Cluster 0 characteristics:
# acoustic blues        0.126672
# metal                 0.102012
# adult standards       0.099227
# urban contemporary    0.093418
# dub                   0.084807
# Name: 0, dtype: float64
#
# Cluster 1 characteristics:
# atl trap          85.328776
# atl hip hop       17.765379
# release_year       1.565346
# acoustic blues     0.126672
# metal              0.102012
# Name: 1, dtype: float64
#
# Cluster 2 characteristics:
# adult standards       10.077866
# release_year           0.641188
# acoustic blues         0.126672
# metal                  0.102012
# urban contemporary     0.093418
# Name: 2, dtype: float64
#
# Cluster 3 characteristics:
# gothic symphonic metal    22.010604
# gothic metal              12.028307
# release_year               0.396470
# acoustic blues             0.126672
# metal                      0.102012
# Name: 3, dtype: float64
#
# Cluster 4 characteristics:
# norwegian black metal    20.672517
# metal                     3.499709
# release_year              0.187883
# acoustic blues            0.126672
# adult standards           0.099227
# Name: 4, dtype: float64
#
# Cluster 5 characteristics:
# punk n roll        60.332413
# release_year        1.132429
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 5, dtype: float64
#
# Cluster 6 characteristics:
# afro-cuban percussion    17.390131
# release_year              0.319647
# acoustic blues            0.126672
# metal                     0.102012
# adult standards           0.099227
# Name: 6, dtype: float64
#
# Cluster 7 characteristics:
# baroque            21.310209
# early music        19.551551
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 7, dtype: float64
#
# Cluster 8 characteristics:
# ska argentino      12.974931
# latin rock          6.510132
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 8, dtype: float64
#
# Cluster 9 characteristics:
# socal pop punk     15.547776
# acoustic blues      0.126672
# release_year        0.112669
# metal               0.102012
# adult standards     0.099227
# Name: 9, dtype: float64
#
# Cluster 10 characteristics:
# west coast rap     15.293895
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# release_year        0.094359
# Name: 10, dtype: float64
#
# Cluster 11 characteristics:
# australian electropop    49.257825
# alternative dance        16.705596
# release_year              0.531155
# acoustic blues            0.126672
# metal                     0.102012
# Name: 11, dtype: float64
#
# Cluster 12 characteristics:
# gospel blues       21.310209
# acoustic blues      7.894412
# release_year        0.797659
# metal               0.102012
# adult standards     0.099227
# Name: 12, dtype: float64
#
# Cluster 13 characteristics:
# hardcore           18.594674
# release_year        0.460853
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 13, dtype: float64
#
# Cluster 14 characteristics:
# new orleans blues    18.165902
# acoustic blues        4.248465
# release_year          0.204281
# metal                 0.102012
# adult standards       0.099227
# Name: 14, dtype: float64
#
# Cluster 15 characteristics:
# deep ragga         16.705596
# release_year        0.161141
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 15, dtype: float64
#
# Cluster 16 characteristics:
# boy band              22.010604
# urban contemporary     4.225767
# release_year           0.372419
# acoustic blues         0.126672
# metal                  0.102012
# Name: 16, dtype: float64
#
# Cluster 17 characteristics:
# c-pop              16.095696
# release_year        0.369670
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 17, dtype: float64
#
# Cluster 18 characteristics:
# pagan black metal    18.594674
# metal                 3.671219
# release_year          0.472746
# acoustic blues        0.126672
# adult standards       0.099227
# Name: 18, dtype: float64
#
# Cluster 19 characteristics:
# accordion          22.010604
# release_year        0.208873
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 19, dtype: float64
#
# Cluster 20 characteristics:
# mpb                13.993242
# release_year        0.530986
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 20, dtype: float64
#
# Cluster 21 characteristics:
# afropop            18.594674
# release_year        0.129161
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 21, dtype: float64
#
# Cluster 22 characteristics:
# classic finnish pop    14.600564
# release_year            0.277831
# acoustic blues          0.126672
# metal                   0.102012
# adult standards         0.099227
# Name: 22, dtype: float64
#
# Cluster 23 characteristics:
# dub                11.791457
# release_year        0.450771
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 23, dtype: float64
#
# Cluster 24 characteristics:
# symphonic rock     20.088692
# release_year        1.092284
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 24, dtype: float64
#
# Cluster 25 characteristics:
# ambient            85.328776
# release_year        1.897990
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 25, dtype: float64
#
# Cluster 26 characteristics:
# athens indie       49.257825
# release_year        1.080258
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 26, dtype: float64
#
# Cluster 27 characteristics:
# indie rock         16.392184
# release_year        0.242544
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 27, dtype: float64
#
# Cluster 28 characteristics:
# emo                19.551551
# release_year        0.426091
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 28, dtype: float64
#
# Cluster 29 characteristics:
# atmospheric sludge    60.332413
# release_year           0.699512
# acoustic blues         0.126672
# metal                  0.102012
# adult standards        0.099227
# Name: 29, dtype: float64
#
# Cluster 30 characteristics:
# bronx hip hop      20.088692
# release_year        0.330731
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 30, dtype: float64
#
# Cluster 31 characteristics:
# ccm                15.051993
# release_year        0.268850
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 31, dtype: float64
#
# Cluster 32 characteristics:
# post-punk argentina    22.010604
# ska argentino           6.013863
# latin rock              5.746995
# release_year            0.570378
# acoustic blues          0.126672
# Name: 32, dtype: float64
#
# Cluster 33 characteristics:
# disco              21.310209
# vocal jazz          6.349221
# adult standards     4.353251
# release_year        1.158424
# acoustic blues      0.126672
# Name: 33, dtype: float64
#
# Cluster 34 characteristics:
# bolero             21.310209
# release_year        0.135818
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 34, dtype: float64
#
# Cluster 35 characteristics:
# jazz               20.672517
# vocal jazz          2.520166
# adult standards     0.499425
# release_year        0.323361
# acoustic blues      0.126672
# Name: 35, dtype: float64
#
# Cluster 36 characteristics:
# colombian pop      19.551551
# release_year        0.224822
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 36, dtype: float64
#
# Cluster 37 characteristics:
# childrens choir    85.328776
# release_year        0.843818
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 37, dtype: float64
#
# Cluster 38 characteristics:
# zolo               16.392184
# release_year        0.747152
# acoustic blues      0.126672
# metal               0.102012
# adult standards     0.099227
# Name: 38, dtype: float64
#
# Cluster 39 characteristics:
# atl hip hop           17.765379
# urban contemporary     2.851481
# release_year           0.243637
# acoustic blues         0.126672
# metal                  0.102012
# Name: 39, dtype: float64
#
# Cluster 40 characteristics:
# acoustic blues        7.894412
# release_year          0.330532
# metal                 0.102012
# adult standards       0.099227
# urban contemporary    0.093418
# Name: 40, dtype: float64
#
# Cluster 41 characteristics:
# womens music          42.655598
# acoustic blues         0.126672
# metal                  0.102012
# adult standards        0.099227
# urban contemporary     0.093418
# Name: 41, dtype: float64
#
# Cluster 42 characteristics:
# metal              9.390023
# gothic metal       4.343106
# release_year       0.363239
# acoustic blues     0.126672
# adult standards    0.099227
# Name: 42, dtype: float64
#
# Cluster 43 characteristics:
# speed metal              22.010604
# norwegian black metal    20.672517
# gothic metal             15.051993
# metal                     9.802721
# release_year              0.266595
# Name: 43, dtype: float64
#
# Cluster 44 characteristics:
# dusseldorf electronic    21.310209
# zolo                      7.137265
# release_year              0.400819
# acoustic blues            0.126672
# metal                     0.102012
# Name: 44, dtype: float64
#
# Cluster 45 characteristics:
# urban contemporary    10.704546
# acoustic blues         0.126672
# metal                  0.102012
# adult standards        0.099227
# dub                    0.084807
# Name: 45, dtype: float64
#
# Cluster 46 characteristics:
# alternative dance    16.705596
# indie rock            6.377200
# release_year          0.508150
# acoustic blues        0.126672
# metal                 0.102012
# Name: 46, dtype: float64
#
# Cluster 47 characteristics:
# suomi rock             17.037605
# classic finnish pop     6.972656
# release_year            0.169208
# acoustic blues          0.126672
# metal                   0.102012
# Name: 47, dtype: float64
#
# Cluster 48 characteristics:
# speed metal        22.010604
# metal               3.199565
# release_year        0.310628
# acoustic blues      0.126672
# adult standards     0.099227
# Name: 48, dtype: float64
#
# Cluster 49 characteristics:
# old school thrash    19.551551
# hardcore             18.594674
# release_year          0.347767
# acoustic blues        0.126672
# metal                 0.102012
# Name: 49, dtype: float64
#
# Cluster 50 characteristics:
# vocal jazz         14.600564
# adult standards     8.381684
# release_year        0.680411
# acoustic blues      0.126672
# metal               0.102012
# Name: 50, dtype: float64
#
# Cluster 51 characteristics:
# old school thrash    19.551551
# metal                 7.101430
# release_year          0.599239
# acoustic blues        0.126672
# adult standards       0.099227
# Name: 51, dtype: float64
#
# Cluster 52 characteristics:
# latin rock            12.407102
# acoustic blues         0.126672
# metal                  0.102012
# adult standards        0.099227
# urban contemporary     0.093418
# Name: 52, dtype: float64

# %%
# Print all column names
print("Column names in the clustered dataset:")
for i, col in enumerate(df_clustered.columns, 1):
    print(f"{i}. {col}")
# Out:
# Column names in the clustered dataset:
# 1. release_year
# 2. childrens choir
# 3. punk n roll
# 4. womens music
# 5. ambient
# 6. athens indie
# 7. atl trap
# 8. atmospheric sludge
# 9. australian electropop
# 10. disco
# 11. early music
# 12. gospel blues
# 13. gothic metal
# 14. gothic symphonic metal
# 15. hardcore
# 16. indie rock
# 17. jazz
# 18. latin rock
# 19. metal
# 20. mpb
# 21. new orleans blues
# 22. norwegian black metal
# 23. old school thrash
# 24. pagan black metal
# 25. post-punk argentina
# 26. ska argentino
# 27. socal pop punk
# 28. speed metal
# 29. suomi rock
# 30. symphonic rock
# 31. urban contemporary
# 32. vocal jazz
# 33. west coast rap
# 34. zolo
# 35. accordion
# 36. acoustic blues
# 37. adult standards
# 38. afro-cuban percussion
# 39. afropop
# 40. alternative dance
# 41. atl hip hop
# 42. baroque
# 43. bolero
# 44. boy band
# 45. bronx hip hop
# 46. c-pop
# 47. ccm
# 48. classic finnish pop
# 49. colombian pop
# 50. deep ragga
# 51. dub
# 52. dusseldorf electronic
# 53. emo
# 54. cluster

# %% [markdown]
# Joining Categorical and Numerical Columns with Cluster Assignments

# %%
# Load previous dataset
df_full = pd.read_csv('../data/5_full_dataset.csv')

# Perform outer join using index
df_merged = pd.merge(df_full[['title', 'artist', 'album', 'is_explicit', 'album_cover']], df_clustered, 
                    left_index=True, right_index=True, 
                    how='outer')

# Save the merged dataset
df_merged.to_csv('../data/7_clustered_dataset.csv', index=False)

# Display basic info about the merged dataset
print("Original full dataset shape:", df_full.shape)
print("Clustered dataset shape:", df_clustered.shape)
print("Merged dataset shape:", df_merged.shape)
print("\nFirst few rows of the merged dataset:")
display(df_merged.head())
# Out:
# Original full dataset shape: (7282, 25)
# Clustered dataset shape: (7282, 54)
# Merged dataset shape: (7282, 59)
#
# First few rows of the merged dataset:
#                                           title                  artist  \
# 0                Je sais que la Terre est plate                 Raphaël
# 1                                     On efface           Julie Zenatti
# 2                               Howells Delight               Anonymous
# 3                                 Martha Served            I Hate Sally
# 4  Zip-a-Dee-Doo-Dah (From "Song of the South")  Orlando Pops Orchestra
#
#                                             album  is_explicit  \
# 0                  Je Sais Que La Terre Est Plate        False
# 1                                   Comme vous...        False
# 2               The Best of the Baltimore Consort        False
# 3                                Don't Worry Lady         True
# 4  Most Amazing Movie, Musical & TV Themes, Vol.6        False
#
#                                          album_cover  release_year  \
# 0  https://i.scdn.co/image/ab67616d0000b2739e6b95...      0.627359
# 1  https://i.scdn.co/image/ab67616d0000b27398d445...      0.338748
# 2  https://i.scdn.co/image/ab67616d0000b27353a906...      0.843818
# 3  https://i.scdn.co/image/ab67616d0000b273e6d949...      0.555206
# 4  https://i.scdn.co/image/ab67616d0000b27349ea4d...      1.637499
#
#    childrens choir  punk n roll  womens music   ambient  ...  bronx hip hop  \
# 0        -0.011719    -0.016575     -0.023444 -0.011719  ...      -0.049779
# 1        -0.011719    -0.016575     -0.023444 -0.011719  ...      -0.049779
# 2        -0.011719    -0.016575     -0.023444 -0.011719  ...      -0.049779
# 3        -0.011719    -0.016575     -0.023444 -0.011719  ...      -0.049779
# 4        -0.011719    -0.016575     -0.023444 -0.011719  ...      -0.049779
#
#       c-pop       ccm  classic finnish pop  colombian pop  deep ragga  \
# 0 -0.062128 -0.066436            -0.068491      -0.051147    -0.05986
# 1 -0.062128 -0.066436            -0.068491      -0.051147    -0.05986
# 2 -0.062128 -0.066436            -0.068491      -0.051147    -0.05986
# 3 -0.062128 -0.066436            -0.068491      -0.051147    -0.05986
# 4 -0.062128 -0.066436            -0.068491      -0.051147    -0.05986
#
#         dub  dusseldorf electronic       emo  cluster
# 0 -0.084807              -0.046926 -0.051147        0
# 1 -0.084807              -0.046926 -0.051147        0
# 2 -0.084807              -0.046926 -0.051147        0
# 3 -0.084807              -0.046926 -0.051147        0
# 4 -0.084807              -0.046926 -0.051147        0
#
# [5 rows x 59 columns]

# %%
# Check for null values in each column
null_counts = df_merged.isnull().sum()

# Display columns with null values and their counts
print("Columns with null values:")
print("------------------------")
for column, null_count in null_counts.items():
    if null_count > 0:
        print(f"{column}: {null_count} null values")

# Get total number of rows with any null value
total_rows_with_nulls = df_merged.isnull().any(axis=1).sum()
print(f"\nTotal rows with at least one null value: {total_rows_with_nulls}")
print(f"Percentage of rows with nulls: {(total_rows_with_nulls/len(df_merged)*100):.2f}%")

# Display a few example rows that contain null values
print("\nExample rows with null values:")
display(df_merged[df_merged.isnull().any(axis=1)].head())
# Out:
# Columns with null values:
# ------------------------
#
# Total rows with at least one null value: 0
# Percentage of rows with nulls: 0.00%
#
# Example rows with null values:
# Empty DataFrame
# Columns: [title, artist, album, is_explicit, album_cover, release_year, childrens choir, punk n roll, womens music, ambient, athens indie, atl trap, atmospheric sludge, australian electropop, disco, early music, gospel blues, gothic metal, gothic symphonic metal, hardcore, indie rock, jazz, latin rock, metal, mpb, new orleans blues, norwegian black metal, old school thrash, pagan black metal, post-punk argentina, ska argentino, socal pop punk, speed metal, suomi rock, symphonic rock, urban contemporary, vocal jazz, west coast rap, zolo, accordion, acoustic blues, adult standards, afro-cuban percussion, afropop, alternative dance, atl hip hop, baroque, bolero, boy band, bronx hip hop, c-pop, ccm, classic finnish pop, colombian pop, deep ragga, dub, dusseldorf electronic, emo, cluster, isHot]
# Index: []
#
# [0 rows x 60 columns]
